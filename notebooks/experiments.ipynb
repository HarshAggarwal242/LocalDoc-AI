# %% [markdown]
# # Experiments scratchpad
#
# Use this notebook for quick prototyping (new prompts, trying a different Ollama model, testing chunk sizes) before promoting the code into the `ingestion/`, `summarization/`, or `rag/` modules.

# %%
import sys
sys.path.append('..')

from summarization.llm import get_llm

llm = get_llm()
print(llm.invoke('Say hello in one sentence.').content)
